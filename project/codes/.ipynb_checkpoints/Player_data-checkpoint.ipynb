# %%
import pandas as pd
from pandas import DataFrame
import csv

# %%
data_dir = "../data/player_Data/players_22.csv"      # 2021/22 시즌 EPL 선수 데이터 경로
fb_data = pd.read_csv(data_dir,encoding='cp949')
# Out:
# C:\Users\SF314-510G\AppData\Local\Temp\ipykernel_4724\3538114551.py:2: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   fb_data = pd.read_csv(data_dir,encoding='cp949')

# %%
EPLteams = ['Arsenal', 'Aston Villa', 'Brentford', 'Brighton & Hove Albion', 'Burnley', 'Chelsea', 'Crystal Palace',
            'Everton', 'Leeds United', 'Leicester City', 'Liverpool', 'Manchester City', 'Manchester United',
            'Newcastle United', 'Norwich City', 'Southampton', 'Tottenham Hotspur', 'Watford', 'West Ham United', 'Wolverhampton Wanderers']
EPL = {}                    # EPL 팀 별 선수 목록 : EPL 딕셔너리 : EPL[ 팀명 ] : [ [선수1], [선수2] ....]

# %% [markdown]
# # epl 팀별 분류

# %%
result = []
for team in EPLteams:
    EPL[team] = []
    print(team)
    for i, row in fb_data.iterrows():
        if row['club_name'] == team:
            EPL[team].append(fb_data.loc[i])
# Out:
# Arsenal
# Aston Villa
# Brentford
# Brighton & Hove Albion
# Burnley
# Chelsea
# Crystal Palace
# Everton
# Leeds United
# Leicester City
# Liverpool
# Manchester City
# Manchester United
# Newcastle United
# Norwich City
# Southampton
# Tottenham Hotspur
# Watford
# West Ham United
# Wolverhampton Wanderers

# %%
for team in EPLteams:
    col = EPL[team][0].keys()
    value_items = [] 
    with open("{0}.csv".format(team),'w+',encoding='utf-8-sig') as f:
        wr = csv.writer(f,quoting=csv.QUOTE_ALL)
        wr.writerow(col)        
        f.close()

# %%
for team in EPLteams:
    with open("{0}.csv".format(team),'a',encoding='utf-8-sig') as f:
        for overall_player_data in EPL[team]:
            value_items = []
            for col in overall_player_data:
                if(type(col) != 'str'):
                    col = str(col)
                else:
                    pass
                value_items.append(col)
                
            wr = csv.writer(f,quoting=csv.QUOTE_ALL)
            wr.writerow(value_items)        
    f.close()

# %%
for overall_player_data in EPL[team]:
    print(overall_player_data)
# Out:
# sofifa_id               204838
# short_name          R. Jiménez
# player_positions            ST
# overall                     83
# potential                   83
#                        ...
# lcb                       60+3
# cb                        60+3
# rcb                       60+3
# rb                        62+3
# gk                        18+3
# Name: 168, Length: 97, dtype: object
# sofifa_id                224293
# short_name          Rúben Neves
# player_positions             CM
# overall                      82
# potential                    87
#                        ...
# lcb                        73+2
# cb                         73+2
# rcb                        73+2
# rb                         74+2
# gk                         19+2
# Name: 255, Length: 97, dtype: object
# sofifa_id                  162347
# short_name          João Moutinho
# player_positions               CM
# overall                        80
# potential                      80
#                         ...
# lcb                          70+3
# cb                           70+3
# rcb                          70+3
# rb                           72+3
# gk                           20+3
# Name: 391, Length: 97, dtype: object
# sofifa_id             210455
# short_name             Jonny
# player_positions    LWB, RWB
# overall                   80
# potential                 81
#                       ...
# lcb                     76+2
# cb                      76+2
# rcb                     76+2
# rb                      78+2
# gk                      16+2
# Name: 447, Length: 97, dtype: object
# sofifa_id                  227928
# short_name          Nélson Semedo
# player_positions          RWB, RB
# overall                        80
# potential                      81
#                         ...
# lcb                          75+2
# cb                           75+2
# rcb                          75+2
# rb                           77+2
# gk                           21+2
# Name: 478, Length: 97, dtype: object
# sofifa_id             202048
# short_name          C. Coady
# player_positions          CB
# overall                   79
# potential                 81
#                       ...
# lcb                     77+2
# cb                      77+2
# rcb                     77+2
# rb                      74+2
# gk                      18+2
# Name: 556, Length: 97, dtype: object
# sofifa_id            202750
# short_name          W. Boly
# player_positions         CB
# overall                  79
# potential                79
#                      ...
# lcb                      79
# cb                       79
# rcb                      79
# rb                     72+2
# gk                     16+2
# Name: 560, Length: 97, dtype: object
# sofifa_id            212442
# short_name          José Sá
# player_positions         GK
# overall                  79
# potential                81
#                      ...
# lcb                    28+2
# cb                     28+2
# rcb                    28+2
# rb                     27+2
# gk                     78+2
# Name: 591, Length: 97, dtype: object
# sofifa_id             208295
# short_name          R. Saïss
# player_positions      CB, CM
# overall                   78
# potential                 78
#                       ...
# lcb                       78
# cb                        78
# rcb                       78
# rb                      73+2
# gk                      18+2
# Name: 742, Length: 97, dtype: object
# sofifa_id                 213956
# short_name          Adama Traoré
# player_positions         RW, RWB
# overall                       78
# potential                     81
#                         ...
# lcb                         53+2
# cb                          53+2
# rcb                         53+2
# rb                          59+2
# gk                          16+2
# Name: 763, Length: 97, dtype: object
# sofifa_id                   226766
# short_name          Daniel Podence
# player_positions       LW, RW, CAM
# overall                         78
# potential                       81
#                          ...
# lcb                           43+2
# cb                            43+2
# rcb                           43+2
# rb                            55+2
# gk                            19+2
# Name: 796, Length: 97, dtype: object
# sofifa_id               238616
# short_name          Pedro Neto
# player_positions        LW, RW
# overall                     78
# potential                   85
#                        ...
# lcb                       44+2
# cb                        44+2
# rcb                       44+2
# rb                        54+2
# gk                        16+2
# Name: 836, Length: 97, dtype: object
# sofifa_id                  212501
# short_name          L. Dendoncker
# player_positions           CM, CB
# overall                        77
# potential                      80
#                         ...
# lcb                          78+2
# cb                           78+2
# rcb                          78+2
# rb                           75+2
# gk                           18+2
# Name: 970, Length: 97, dtype: object
# sofifa_id            244778
# short_name          Trincão
# player_positions     RW, RM
# overall                  76
# potential                85
#                      ...
# lcb                    50+2
# cb                     50+2
# rcb                    50+2
# rb                     56+2
# gk                     17+2
# Name: 1446, Length: 97, dtype: object
# sofifa_id            207707
# short_name           Marçal
# player_positions    LB, LWB
# overall                  75
# potential                75
#                      ...
# lcb                      75
# cb                       75
# rcb                      75
# rb                     73+2
# gk                     17+2
# Name: 1643, Length: 97, dtype: object
# sofifa_id                 242641
# short_name          R. Aït Nouri
# player_positions         LWB, LB
# overall                       73
# potential                     84
#                         ...
# lcb                         66+2
# cb                          66+2
# rcb                         66+2
# rb                          71+2
# gk                          19+2
# Name: 3018, Length: 97, dtype: object
# sofifa_id             163600
# short_name          J. Ruddy
# player_positions          GK
# overall                   70
# potential                 70
#                       ...
# lcb                     26+2
# cb                      26+2
# rcb                     26+2
# rb                      25+2
# gk                      69+1
# Name: 4614, Length: 97, dtype: object
# sofifa_id              245336
# short_name          M. Kilman
# player_positions           CB
# overall                    70
# potential                  78
#                       ...
# lcb                      70+2
# cb                       70+2
# rcb                      70+2
# rb                       66+2
# gk                       17+2
# Name: 5318, Length: 97, dtype: object
# sofifa_id                252037
# short_name          Fábio Silva
# player_positions             ST
# overall                      70
# potential                    85
#                        ...
# lcb                        39+2
# cb                         39+2
# rcb                        39+2
# rb                         42+2
# gk                         17+2
# Name: 5394, Length: 97, dtype: object
# sofifa_id              246763
# short_name          K. Hoever
# player_positions      RWB, RB
# overall                    65
# potential                  80
#                       ...
# lcb                      62+2
# cb                       62+2
# rcb                      62+2
# rb                       62+2
# gk                       17+2
# Name: 10708, Length: 97, dtype: object
# sofifa_id                256666
# short_name          Y. Mosquera
# player_positions             CB
# overall                      64
# potential                    81
#                        ...
# lcb                        64+2
# cb                         64+2
# rcb                        64+2
# rb                         61+2
# gk                         14+2
# Name: 12029, Length: 97, dtype: object
# sofifa_id                 240175
# short_name          Bruno Jordão
# player_positions              CM
# overall                       62
# potential                     73
#                         ...
# lcb                         54+2
# cb                          54+2
# rcb                         54+2
# rb                          55+2
# gk                          14+2
# Name: 13782, Length: 97, dtype: object
# sofifa_id                242980
# short_name           M. Shabani
# player_positions    CAM, CM, ST
# overall                      62
# potential                    72
#                        ...
# lcb                        43+2
# cb                         43+2
# rcb                        43+2
# rb                         47+2
# gk                         13+2
# Name: 13840, Length: 97, dtype: object
# sofifa_id                246002
# short_name          L. Matheson
# player_positions        RWB, RB
# overall                      62
# potential                    81
#                        ...
# lcb                        54+2
# cb                         54+2
# rcb                        54+2
# rb                         59+2
# gk                         15+2
# Name: 13907, Length: 97, dtype: object
# sofifa_id               261224
# short_name          Hugo Bueno
# player_positions           LWB
# overall                     59
# potential                   81
#                        ...
# lcb                       56+2
# cb                        56+2
# rcb                       56+2
# rb                        57+2
# gk                        16+2
# Name: 16360, Length: 97, dtype: object
# sofifa_id                254113
# short_name          C. Campbell
# player_positions            CAM
# overall                      58
# potential                    78
#                        ...
# lcb                        45+2
# cb                         45+2
# rcb                        45+2
# rb                         50+2
# gk                         14+2
# Name: 16699, Length: 97, dtype: object
# sofifa_id                      256449
# short_name          Christian Marques
# player_positions                   CB
# overall                            58
# potential                          80
#                           ...
# lcb                              58+2
# cb                               58+2
# rcb                              58+2
# rb                               55+2
# gk                               16+2
# Name: 16742, Length: 97, dtype: object
# sofifa_id             261032
# short_name          J. Hodge
# player_positions     CDM, CM
# overall                   55
# potential                 72
#                       ...
# lcb                     52+2
# cb                      52+2
# rcb                     52+2
# rb                      52+2
# gk                      16+2
# Name: 18014, Length: 97, dtype: object
# sofifa_id                251590
# short_name          L. Richards
# player_positions        CB, LWB
# overall                      54
# potential                    74
#                        ...
# lcb                        54+2
# cb                         54+2
# rcb                        54+2
# rb                         52+2
# gk                         14+2
# Name: 18204, Length: 97, dtype: object
# sofifa_id              253461
# short_name          L. Cundle
# player_positions           CM
# overall                    54
# potential                  74
#                       ...
# lcb                      46+2
# cb                       46+2
# rcb                      46+2
# rb                       50+2
# gk                       15+2
# Name: 18221, Length: 97, dtype: object
# sofifa_id             258532
# short_name          C. Carty
# player_positions          ST
# overall                   54
# potential                 69
#                       ...
# lcb                     34+2
# cb                      34+2
# rcb                     34+2
# rb                      39+2
# gk                      15+2
# Name: 18272, Length: 97, dtype: object
# sofifa_id               244507
# short_name          P. Estrada
# player_positions        CB, CM
# overall                     51
# potential                   65
#                        ...
# lcb                       51+2
# cb                        51+2
# rcb                       51+2
# rb                        50+2
# gk                        12+2
# Name: 18877, Length: 97, dtype: object
